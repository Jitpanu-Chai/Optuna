# %% [markdown]
# <a href="https://colab.research.google.com/github/Jitpanu-Chai/Optuna/blob/main/Optuna_MNIST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -qq optuna
# Out:
#      |████████████████████████████████| 308 kB 9.6 MB/s
#      |████████████████████████████████| 81 kB 12.6 MB/s
#      |████████████████████████████████| 210 kB 66.6 MB/s
#      |████████████████████████████████| 78 kB 7.6 MB/s
#      |████████████████████████████████| 113 kB 100.0 MB/s
#      |████████████████████████████████| 49 kB 6.9 MB/s
#      |████████████████████████████████| 146 kB 91.4 MB/s
#   Building wheel for pyperclip (setup.py) ... done

# %%
import os
import torch 
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.utils.data
from torchvision import datasets
from torchvision import transforms
import optuna

# %% [markdown]
# # **PyTorch**

# %%
DEVICE = torch.device("cuda") #torch.device("cpu")
BATCHSIZE = 128
CLASSES = 10
DIR = os.getcwd()
EPOCHS = 10
LOG_INTERVAL = 10
N_TRAIN_EXAMPLES = BATCHSIZE * 30
N_VALID_EXAMPLES = BATCHSIZE * 10

# %% [markdown]
# # **Optuna+Model construct**

# %%
def define_model(trial):
    #optmize number of layer ,hidden unit drop out
    n_layers = trial.suggest_int("n_layers",1,3)
    layers=[]

    in_features = 28*28
    for i in range(n_layers):
        out_features = trial.suggest_int("n_units_l{}".format(i),4,128)
        layers.append(nn.Linear(in_features,out_features))
        layers.append(nn.ReLU())
        p= trial.suggest_float("dropout_l{}".format(i),0.2,0.5)
        layers.append(nn.Dropout(p))

        in_features=out_features
    layers.append(nn.Linear(in_features,CLASSES))
    layers.append(nn.LogSoftmax(dim=1))

    return nn.Sequential(*layers)

# %%
def get_mnist():
    # Load FashionMNIST dataset.
    train_loader = torch.utils.data.DataLoader(
        datasets.FashionMNIST(DIR, train=True, download=True, transform=transforms.ToTensor()),
        batch_size=BATCHSIZE,
        shuffle=True,
    )
    valid_loader = torch.utils.data.DataLoader(
        datasets.FashionMNIST(DIR, train=False, transform=transforms.ToTensor()),
        batch_size=BATCHSIZE,
        shuffle=True,
    )

    return train_loader, valid_loader

# %% [markdown]
# # **Optuna Area**

# %%
def objective(trial):
    #code here
    #create model
    model = define_model(trial).to(DEVICE)

    #create optimize
    optimizer_name=trial.suggest_categorical("optimizers",["Adam","RMSprop","SGD"])
    lr= trial.suggest_float("lr",1e-5,1e-1,log=True)
    optimizer= getattr(optim, optimizer_name)(model.parameters(),lr=lr)

    #get MNIST dataset
    train_loader,valid_loader = get_mnist()

    #train model
    for eporch in range(EPOCHS):
        #train torch code model
        model.train()
        for batch_idx, (data, target) in enumerate(train_loader):
            # Limiting training data for faster epochs.
            if batch_idx * BATCHSIZE >= N_TRAIN_EXAMPLES:
                break

            data, target = data.view(data.size(0), -1).to(DEVICE), target.to(DEVICE)

            optimizer.zero_grad()
            output = model(data)
            loss = F.nll_loss(output, target)
            loss.backward()
            optimizer.step()

        # Validation of the model.
        model.eval()
        correct = 0
        with torch.no_grad():
            for batch_idx, (data, target) in enumerate(valid_loader):
                # Limiting validation data.
                if batch_idx * BATCHSIZE >= N_VALID_EXAMPLES:
                    break
                data, target = data.view(data.size(0), -1).to(DEVICE), target.to(DEVICE)
                output = model(data)
                # Get the index of the max log-probability.
                pred = output.argmax(dim=1, keepdim=True)
                correct += pred.eq(target.view_as(pred)).sum().item()

        accuracy = correct / min(len(valid_loader.dataset), N_VALID_EXAMPLES)

        trial.report(accuracy,eporch) #report to optuna to check status its worth or not
        #handing prun algo
        if trial.should_prune():
            raise optuna.exceptions.TrialPruned()    
    return accuracy

# %%
# if __name__ == 'main':

study = optuna.create_study(direction='maximize') #select own direction or default
study.optimize(objective,n_trials=100,timeout=600) #number of trials

pruned_trials = [t for t in study.trials if t.state == optuna.trial.TrialState.PRUNED]
complete_trials = [t for t in study.trials if t.state == optuna.trial.TrialState.COMPLETE]

print('study statistic')
print('number of finished trials: ',len(study.trials))
print('number of proned trials: ',len(pruned_trials))
print('number of completed trials: ',len(complete_trials))

print("Best trials:")
trial =study.best_trial
print('Value', trial.value)

print('Params')
for key,value in trial.params.items():
    print('{}:{}'.format(key,value))
# Out:
# [I 2022-04-17 13:12:05,027] A new study created in memory with name: no-name-cd19d78a-4d57-4cee-abc9-c1917b05d294
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz to /content/FashionMNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/26421880 [00:00<?, ?it/s]
# Extracting /content/FashionMNIST/raw/train-images-idx3-ubyte.gz to /content/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz to /content/FashionMNIST/raw/train-labels-idx1-ubyte.gz
#   0%|          | 0/29515 [00:00<?, ?it/s]
# Extracting /content/FashionMNIST/raw/train-labels-idx1-ubyte.gz to /content/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz to /content/FashionMNIST/raw/t10k-images-idx3-ubyte.gz
#   0%|          | 0/4422102 [00:00<?, ?it/s]
# Extracting /content/FashionMNIST/raw/t10k-images-idx3-ubyte.gz to /content/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz to /content/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz
#   0%|          | 0/5148 [00:00<?, ?it/s]
# Extracting /content/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz to /content/FashionMNIST/raw
# [I 2022-04-17 13:12:15,876] Trial 0 finished with value: 0.81171875 and parameters: {'n_layers': 2, 'n_units_l0': 119, 'dropout_l0': 0.28751041006938305, 'n_units_l1': 117, 'dropout_l1': 0.34686293198243245, 'optimizers': 'RMSprop', 'lr': 0.002967685174047254}. Best is trial 0 with value: 0.81171875.
# [I 2022-04-17 13:12:19,788] Trial 1 finished with value: 0.81484375 and parameters: {'n_layers': 1, 'n_units_l0': 86, 'dropout_l0': 0.4898870352695034, 'optimizers': 'RMSprop', 'lr': 0.0015826085264511874}. Best is trial 1 with value: 0.81484375.
# [I 2022-04-17 13:12:23,747] Trial 2 finished with value: 0.46796875 and parameters: {'n_layers': 2, 'n_units_l0': 15, 'dropout_l0': 0.24989929592970755, 'n_units_l1': 67, 'dropout_l1': 0.23137251238147208, 'optimizers': 'Adam', 'lr': 0.04398416090755745}. Best is trial 1 with value: 0.81484375.
# [I 2022-04-17 13:12:27,650] Trial 3 finished with value: 0.7265625 and parameters: {'n_layers': 1, 'n_units_l0': 106, 'dropout_l0': 0.32365611600696276, 'optimizers': 'RMSprop', 'lr': 0.01895503873778496}. Best is trial 1 with value: 0.81484375.
# [I 2022-04-17 13:12:31,620] Trial 4 finished with value: 0.2890625 and parameters: {'n_layers': 3, 'n_units_l0': 14, 'dropout_l0': 0.3724001207019961, 'n_units_l1': 107, 'dropout_l1': 0.44443436058143526, 'n_units_l2': 45, 'dropout_l2': 0.4287349671176366, 'optimizers': 'RMSprop', 'lr': 2.4364957942197397e-05}. Best is trial 1 with value: 0.81484375.
# [I 2022-04-17 13:12:32,024] Trial 5 pruned.
# [I 2022-04-17 13:12:32,446] Trial 6 pruned.
# [I 2022-04-17 13:12:32,865] Trial 7 pruned.
# [I 2022-04-17 13:12:33,284] Trial 8 pruned.
# [I 2022-04-17 13:12:33,707] Trial 9 pruned.
# [I 2022-04-17 13:12:34,155] Trial 10 pruned.
# [I 2022-04-17 13:12:38,013] Trial 11 finished with value: 0.8328125 and parameters: {'n_layers': 1, 'n_units_l0': 127, 'dropout_l0': 0.28129498239305467, 'optimizers': 'RMSprop', 'lr': 0.004747868425392245}. Best is trial 11 with value: 0.8328125.
# [I 2022-04-17 13:12:38,430] Trial 12 pruned.
# [I 2022-04-17 13:12:38,846] Trial 13 pruned.
# [I 2022-04-17 13:12:39,275] Trial 14 pruned.
# [I 2022-04-17 13:12:40,066] Trial 15 pruned.
# [I 2022-04-17 13:12:40,508] Trial 16 pruned.
# [I 2022-04-17 13:12:41,060] Trial 17 pruned.
# [I 2022-04-17 13:12:41,623] Trial 18 pruned.
# [I 2022-04-17 13:12:42,079] Trial 19 pruned.
# [I 2022-04-17 13:12:42,542] Trial 20 pruned.
# [I 2022-04-17 13:12:42,984] Trial 21 pruned.
# [I 2022-04-17 13:12:43,429] Trial 22 pruned.
# [I 2022-04-17 13:12:47,268] Trial 23 finished with value: 0.834375 and parameters: {'n_layers': 1, 'n_units_l0': 115, 'dropout_l0': 0.32820105786471565, 'optimizers': 'RMSprop', 'lr': 0.0023527684359174444}. Best is trial 23 with value: 0.834375.
# [I 2022-04-17 13:12:48,465] Trial 24 pruned.
# [I 2022-04-17 13:12:52,323] Trial 25 finished with value: 0.834375 and parameters: {'n_layers': 1, 'n_units_l0': 96, 'dropout_l0': 0.31310803244853935, 'optimizers': 'RMSprop', 'lr': 0.001809823502092312}. Best is trial 23 with value: 0.834375.
# [I 2022-04-17 13:12:56,164] Trial 26 pruned.
# [I 2022-04-17 13:13:00,481] Trial 27 pruned.
# [I 2022-04-17 13:13:00,895] Trial 28 pruned.
# [I 2022-04-17 13:13:01,342] Trial 29 pruned.
# [I 2022-04-17 13:13:01,775] Trial 30 pruned.
# [I 2022-04-17 13:13:05,798] Trial 31 finished with value: 0.82109375 and parameters: {'n_layers': 1, 'n_units_l0': 87, 'dropout_l0': 0.34290202525151203, 'optimizers': 'RMSprop', 'lr': 0.001264333943972827}. Best is trial 23 with value: 0.834375.
# [I 2022-04-17 13:13:09,764] Trial 32 finished with value: 0.79453125 and parameters: {'n_layers': 1, 'n_units_l0': 78, 'dropout_l0': 0.34035626155988663, 'optimizers': 'RMSprop', 'lr': 0.001233505744948805}. Best is trial 23 with value: 0.834375.
# [I 2022-04-17 13:13:10,933] Trial 33 pruned.
# [I 2022-04-17 13:13:11,349] Trial 34 pruned.
# [I 2022-04-17 13:13:11,808] Trial 35 pruned.
# [I 2022-04-17 13:13:12,283] Trial 36 pruned.
# [I 2022-04-17 13:13:12,722] Trial 37 pruned.
# [I 2022-04-17 13:13:13,154] Trial 38 pruned.
# [I 2022-04-17 13:13:13,575] Trial 39 pruned.
# [I 2022-04-17 13:13:14,016] Trial 40 pruned.
# [I 2022-04-17 13:13:14,437] Trial 41 pruned.
# [I 2022-04-17 13:13:14,883] Trial 42 pruned.
# [I 2022-04-17 13:13:15,357] Trial 43 pruned.
# [I 2022-04-17 13:13:15,821] Trial 44 pruned.
# [I 2022-04-17 13:13:20,553] Trial 45 pruned.
# [I 2022-04-17 13:13:21,015] Trial 46 pruned.
# [I 2022-04-17 13:13:22,001] Trial 47 pruned.
# [I 2022-04-17 13:13:22,434] Trial 48 pruned.
# [I 2022-04-17 13:13:22,848] Trial 49 pruned.
# [I 2022-04-17 13:13:23,302] Trial 50 pruned.
# [I 2022-04-17 13:13:23,757] Trial 51 pruned.
# [I 2022-04-17 13:13:24,230] Trial 52 pruned.
# [I 2022-04-17 13:13:24,682] Trial 53 pruned.
# [I 2022-04-17 13:13:25,126] Trial 54 pruned.
# [I 2022-04-17 13:13:29,353] Trial 55 finished with value: 0.8140625 and parameters: {'n_layers': 1, 'n_units_l0': 118, 'dropout_l0': 0.34106573333242735, 'optimizers': 'RMSprop', 'lr': 0.003456556651556765}. Best is trial 23 with value: 0.834375.
# [I 2022-04-17 13:13:29,768] Trial 56 pruned.
# [I 2022-04-17 13:13:33,622] Trial 57 finished with value: 0.81015625 and parameters: {'n_layers': 1, 'n_units_l0': 101, 'dropout_l0': 0.3328754738937042, 'optimizers': 'Adam', 'lr': 0.011441680898574325}. Best is trial 23 with value: 0.834375.
# [I 2022-04-17 13:13:34,052] Trial 58 pruned.
# [I 2022-04-17 13:13:34,481] Trial 59 pruned.
# [I 2022-04-17 13:13:34,905] Trial 60 pruned.
# [I 2022-04-17 13:13:35,702] Trial 61 pruned.
# [I 2022-04-17 13:13:36,510] Trial 62 pruned.
# [I 2022-04-17 13:13:36,937] Trial 63 pruned.
# [I 2022-04-17 13:13:37,357] Trial 64 pruned.
# [I 2022-04-17 13:13:37,777] Trial 65 pruned.
# [I 2022-04-17 13:13:38,254] Trial 66 pruned.
# [I 2022-04-17 13:13:39,433] Trial 67 pruned.
# [I 2022-04-17 13:13:39,872] Trial 68 pruned.
# [I 2022-04-17 13:13:40,290] Trial 69 pruned.
# [I 2022-04-17 13:13:40,711] Trial 70 pruned.
# [I 2022-04-17 13:13:44,682] Trial 71 finished with value: 0.81640625 and parameters: {'n_layers': 1, 'n_units_l0': 102, 'dropout_l0': 0.3349973423341342, 'optimizers': 'Adam', 'lr': 0.013431911018214714}. Best is trial 23 with value: 0.834375.
# [I 2022-04-17 13:13:45,098] Trial 72 pruned.
# [I 2022-04-17 13:13:49,239] Trial 73 finished with value: 0.8265625 and parameters: {'n_layers': 1, 'n_units_l0': 98, 'dropout_l0': 0.3714788117905429, 'optimizers': 'Adam', 'lr': 0.0097695635323869}. Best is trial 23 with value: 0.834375.
# [I 2022-04-17 13:13:50,167] Trial 74 pruned.
# [I 2022-04-17 13:13:50,594] Trial 75 pruned.
# [I 2022-04-17 13:13:51,785] Trial 76 pruned.
# [I 2022-04-17 13:13:52,220] Trial 77 pruned.
# [I 2022-04-17 13:13:56,112] Trial 78 finished with value: 0.83125 and parameters: {'n_layers': 1, 'n_units_l0': 87, 'dropout_l0': 0.33087867582888186, 'optimizers': 'Adam', 'lr': 0.004635462134425978}. Best is trial 23 with value: 0.834375.
# [I 2022-04-17 13:13:56,540] Trial 79 pruned.
# [I 2022-04-17 13:14:00,487] Trial 80 finished with value: 0.815625 and parameters: {'n_layers': 1, 'n_units_l0': 76, 'dropout_l0': 0.3817516488252587, 'optimizers': 'Adam', 'lr': 0.009783120182378887}. Best is trial 23 with value: 0.834375.
# [I 2022-04-17 13:14:04,520] Trial 81 finished with value: 0.82421875 and parameters: {'n_layers': 1, 'n_units_l0': 75, 'dropout_l0': 0.385179188039104, 'optimizers': 'Adam', 'lr': 0.009540480113889303}. Best is trial 23 with value: 0.834375.
# [I 2022-04-17 13:14:08,559] Trial 82 finished with value: 0.82109375 and parameters: {'n_layers': 1, 'n_units_l0': 74, 'dropout_l0': 0.38050461191454815, 'optimizers': 'Adam', 'lr': 0.011724013482357557}. Best is trial 23 with value: 0.834375.
# [I 2022-04-17 13:14:08,982] Trial 83 pruned.
# [I 2022-04-17 13:14:09,823] Trial 84 pruned.
# [I 2022-04-17 13:14:10,263] Trial 85 pruned.
# [I 2022-04-17 13:14:14,165] Trial 86 finished with value: 0.8078125 and parameters: {'n_layers': 1, 'n_units_l0': 75, 'dropout_l0': 0.3754642899096172, 'optimizers': 'Adam', 'lr': 0.006759419021219871}. Best is trial 23 with value: 0.834375.
# [I 2022-04-17 13:14:14,582] Trial 87 pruned.
# [I 2022-04-17 13:14:15,005] Trial 88 pruned.
# [I 2022-04-17 13:14:17,370] Trial 89 pruned.
# [I 2022-04-17 13:14:18,594] Trial 90 pruned.
# [I 2022-04-17 13:14:20,170] Trial 91 pruned.
# [I 2022-04-17 13:14:20,596] Trial 92 pruned.
# [I 2022-04-17 13:14:21,021] Trial 93 pruned.
# [I 2022-04-17 13:14:24,908] Trial 94 finished with value: 0.83125 and parameters: {'n_layers': 1, 'n_units_l0': 76, 'dropout_l0': 0.400320615532988, 'optimizers': 'Adam', 'lr': 0.006804448542078162}. Best is trial 23 with value: 0.834375.
# [I 2022-04-17 13:14:28,797] Trial 95 finished with value: 0.81640625 and parameters: {'n_layers': 1, 'n_units_l0': 94, 'dropout_l0': 0.398549181851208, 'optimizers': 'Adam', 'lr': 0.007811550093949133}. Best is trial 23 with value: 0.834375.
# [I 2022-04-17 13:14:29,230] Trial 96 pruned.
# [I 2022-04-17 13:14:29,653] Trial 97 pruned.
# [I 2022-04-17 13:14:30,083] Trial 98 pruned.
# [I 2022-04-17 13:14:31,685] Trial 99 pruned.
# study statistic
# number of finished trials:  100
# number of proned trials:  79
# number of completed trials:  21
# Best trials:
# Value 0.834375
# Params
# n_layers:1
# n_units_l0:115
# dropout_l0:0.32820105786471565
# optimizers:RMSprop
# lr:0.0023527684359174444

# %% [markdown]
# # **Tensorflow**

# %%
import tensorflow as tf
from tensorflow.keras.datasets import fashion_mnist

# %%
N_TRAIN_EXAMPLES = 3000
N_VALID_EXAMPLES = 1000
BATCHSIZE = 128
CLASSES = 10
EPOCHS = 1

# %%
def create_model(trial):
    # We optimize the numbers of layers, their units and weight decay parameter.
    n_layers = trial.suggest_int("n_layers", 1, 3)
    weight_decay = trial.suggest_float("weight_decay", 1e-10, 1e-3, log=True)
    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Flatten())
    for i in range(n_layers):
        num_hidden = trial.suggest_int("n_units_l{}".format(i), 4, 128, log=True)
        model.add(
            tf.keras.layers.Dense(
                num_hidden,
                activation="relu",
                kernel_regularizer=tf.keras.regularizers.l2(weight_decay),
            )
        )
    model.add(
        tf.keras.layers.Dense(CLASSES, kernel_regularizer=tf.keras.regularizers.l2(weight_decay))
    )
    return model

# %%
def create_optimizer(trial):
    # We optimize the choice of optimizers as well as their parameters.
    kwargs = {}
    optimizer_options = ["RMSprop", "Adam", "SGD"]
    optimizer_selected = trial.suggest_categorical("optimizer", optimizer_options)
    if optimizer_selected == "RMSprop":
        kwargs["learning_rate"] = trial.suggest_float(
            "rmsprop_learning_rate", 1e-5, 1e-1, log=True
        )
        kwargs["decay"] = trial.suggest_float("rmsprop_decay", 0.85, 0.99)
        kwargs["momentum"] = trial.suggest_float("rmsprop_momentum", 1e-5, 1e-1, log=True)
    elif optimizer_selected == "Adam":
        kwargs["learning_rate"] = trial.suggest_float("adam_learning_rate", 1e-5, 1e-1, log=True)
    elif optimizer_selected == "SGD":
        kwargs["learning_rate"] = trial.suggest_float(
            "sgd_opt_learning_rate", 1e-5, 1e-1, log=True
        )
        kwargs["momentum"] = trial.suggest_float("sgd_opt_momentum", 1e-5, 1e-1, log=True)

    optimizer = getattr(tf.optimizers, optimizer_selected)(**kwargs)
    return optimizer

# %%
def learn(model, optimizer, dataset, mode="eval"):
    accuracy = tf.metrics.Accuracy("accuracy", dtype=tf.float32)

    for batch, (images, labels) in enumerate(dataset):
        with tf.GradientTape() as tape:
            logits = model(images, training=(mode == "train"))
            loss_value = tf.reduce_mean(
                tf.nn.sparse_softmax_cross_entropy_with_logits(logits=logits, labels=labels)
            )
            if mode == "eval":
                accuracy(
                    tf.argmax(logits, axis=1, output_type=tf.int64), tf.cast(labels, tf.int64)
                )
            else:
                grads = tape.gradient(loss_value, model.variables)
                optimizer.apply_gradients(zip(grads, model.variables))

    if mode == "eval":        
        return accuracy

# %%
def get_fashion_mnist():
    (x_train, y_train), (x_valid, y_valid) = fashion_mnist.load_data()
    x_train = x_train.astype("float32") / 255
    x_valid = x_valid.astype("float32") / 255

    y_train = y_train.astype("int32")
    y_valid = y_valid.astype("int32")

    train_ds = tf.data.Dataset.from_tensor_slices((x_train, y_train))
    train_ds = train_ds.shuffle(60000).batch(BATCHSIZE).take(N_TRAIN_EXAMPLES)

    valid_ds = tf.data.Dataset.from_tensor_slices((x_valid, y_valid))
    valid_ds = valid_ds.shuffle(10000).batch(BATCHSIZE).take(N_VALID_EXAMPLES)
    return train_ds, valid_ds

# %%
def objective(trial):
    # Get MNIST data.
    train_ds, valid_ds = get_fashion_mnist()

    # Build model and optimizer.
    model = create_model(trial)
    optimizer = create_optimizer(trial)

    # Training and validating cycle.
    with tf.device("/cpu:0"):
        for _ in range(EPOCHS):
            learn(model, optimizer, train_ds, "train")

        accuracy = learn(model, optimizer, valid_ds, "eval")    

    # Return last validation accuracy.
    return accuracy.result()

# %% [markdown]
# # **Optuna Area**

# %%
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=100)

print("Number of finished trials: ", len(study.trials))

print("Best trial:")
trial = study.best_trial

print("  Value: ", trial.value)

print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))
# Out:
# [I 2022-04-17 13:14:49,838] A new study created in memory with name: no-name-c2e15266-fda3-4fa9-9af5-a1165f5d9404
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# 40960/29515 [=========================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# 26435584/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 16384/5148 [===============================================================================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# 4431872/4422102 [==============================] - 0s 0us/step
# [I 2022-04-17 13:15:22,613] Trial 0 finished with value: 0.10329999774694443 and parameters: {'n_layers': 3, 'weight_decay': 3.966398725390108e-09, 'n_units_l0': 23, 'n_units_l1': 5, 'n_units_l2': 16, 'optimizer': 'RMSprop', 'rmsprop_learning_rate': 1.3301158777449405e-05, 'rmsprop_decay': 0.9524280240216382, 'rmsprop_momentum': 1.4101409803623335e-05}. Best is trial 0 with value: 0.10329999774694443.
# [I 2022-04-17 13:15:50,666] Trial 1 finished with value: 0.36489999294281006 and parameters: {'n_layers': 2, 'weight_decay': 7.494692479278656e-09, 'n_units_l0': 7, 'n_units_l1': 62, 'optimizer': 'RMSprop', 'rmsprop_learning_rate': 0.006868881557875344, 'rmsprop_decay': 0.924427881508892, 'rmsprop_momentum': 7.823227124855227e-05}. Best is trial 1 with value: 0.36489999294281006.
# [I 2022-04-17 13:16:25,396] Trial 2 finished with value: 0.8090000152587891 and parameters: {'n_layers': 3, 'weight_decay': 3.69329139037261e-09, 'n_units_l0': 13, 'n_units_l1': 7, 'n_units_l2': 51, 'optimizer': 'Adam', 'adam_learning_rate': 0.00013624029667121893}. Best is trial 2 with value: 0.8090000152587891.
# [I 2022-04-17 13:16:59,583] Trial 3 finished with value: 0.10930000245571136 and parameters: {'n_layers': 3, 'weight_decay': 9.161563885243226e-05, 'n_units_l0': 77, 'n_units_l1': 38, 'n_units_l2': 4, 'optimizer': 'RMSprop', 'rmsprop_learning_rate': 5.9261127274211e-05, 'rmsprop_decay': 0.9864011688483549, 'rmsprop_momentum': 3.0592876308938135e-05}. Best is trial 2 with value: 0.8090000152587891.
# [I 2022-04-17 13:17:26,903] Trial 4 finished with value: 0.17790000140666962 and parameters: {'n_layers': 1, 'weight_decay': 1.9835305477940926e-05, 'n_units_l0': 77, 'optimizer': 'RMSprop', 'rmsprop_learning_rate': 0.00010636516464234566, 'rmsprop_decay': 0.8894573513492576, 'rmsprop_momentum': 0.00021310454911334937}. Best is trial 2 with value: 0.8090000152587891.
# [I 2022-04-17 13:17:56,742] Trial 5 finished with value: 0.10000000149011612 and parameters: {'n_layers': 2, 'weight_decay': 9.905871150269408e-05, 'n_units_l0': 5, 'n_units_l1': 46, 'optimizer': 'Adam', 'adam_learning_rate': 0.03666453209559281}. Best is trial 2 with value: 0.8090000152587891.
# [I 2022-04-17 13:18:25,748] Trial 6 finished with value: 0.14020000398159027 and parameters: {'n_layers': 2, 'weight_decay': 5.946081632813916e-10, 'n_units_l0': 22, 'n_units_l1': 97, 'optimizer': 'RMSprop', 'rmsprop_learning_rate': 9.63387077504763e-05, 'rmsprop_decay': 0.9143495279010647, 'rmsprop_momentum': 0.006197606963197894}. Best is trial 2 with value: 0.8090000152587891.
# [I 2022-04-17 13:18:49,689] Trial 7 finished with value: 0.580299973487854 and parameters: {'n_layers': 1, 'weight_decay': 1.259395000658853e-10, 'n_units_l0': 9, 'optimizer': 'RMSprop', 'rmsprop_learning_rate': 0.009005036887332906, 'rmsprop_decay': 0.8752781984436189, 'rmsprop_momentum': 1.9276400669614592e-05}. Best is trial 2 with value: 0.8090000152587891.
# [I 2022-04-17 13:19:16,938] Trial 8 finished with value: 0.11680000275373459 and parameters: {'n_layers': 1, 'weight_decay': 2.7373756593688335e-09, 'n_units_l0': 81, 'optimizer': 'RMSprop', 'rmsprop_learning_rate': 2.343750733342158e-05, 'rmsprop_decay': 0.8974951313183576, 'rmsprop_momentum': 0.00028274339865936134}. Best is trial 2 with value: 0.8090000152587891.
# [I 2022-04-17 13:19:39,345] Trial 9 finished with value: 0.8342999815940857 and parameters: {'n_layers': 1, 'weight_decay': 2.656731917250906e-06, 'n_units_l0': 20, 'optimizer': 'SGD', 'sgd_opt_learning_rate': 0.028742322158234204, 'sgd_opt_momentum': 1.592027129710285e-05}. Best is trial 9 with value: 0.8342999815940857.
# [I 2022-04-17 13:20:02,486] Trial 10 finished with value: 0.8413000106811523 and parameters: {'n_layers': 1, 'weight_decay': 5.931616358471303e-07, 'n_units_l0': 37, 'optimizer': 'SGD', 'sgd_opt_learning_rate': 0.04005477300370641, 'sgd_opt_momentum': 1.1442788905385756e-05}. Best is trial 10 with value: 0.8413000106811523.
# [I 2022-04-17 13:20:25,468] Trial 11 finished with value: 0.8447999954223633 and parameters: {'n_layers': 1, 'weight_decay': 7.897332637128771e-07, 'n_units_l0': 37, 'optimizer': 'SGD', 'sgd_opt_learning_rate': 0.03841801025406555, 'sgd_opt_momentum': 1.2846635733486694e-05}. Best is trial 11 with value: 0.8447999954223633.
# [I 2022-04-17 13:20:48,638] Trial 12 finished with value: 0.859499990940094 and parameters: {'n_layers': 1, 'weight_decay': 1.2265623916567226e-07, 'n_units_l0': 48, 'optimizer': 'SGD', 'sgd_opt_learning_rate': 0.07088358703810657, 'sgd_opt_momentum': 1.146037478911825e-05}. Best is trial 12 with value: 0.859499990940094.
# [I 2022-04-17 13:21:11,793] Trial 13 finished with value: 0.8557000160217285 and parameters: {'n_layers': 1, 'weight_decay': 1.9114895692909753e-07, 'n_units_l0': 41, 'optimizer': 'SGD', 'sgd_opt_learning_rate': 0.0996360660047187, 'sgd_opt_momentum': 0.08264789848413526}. Best is trial 12 with value: 0.859499990940094.
# [I 2022-04-17 13:21:38,704] Trial 14 finished with value: 0.1737000048160553 and parameters: {'n_layers': 2, 'weight_decay': 6.84209569017147e-08, 'n_units_l0': 42, 'n_units_l1': 11, 'optimizer': 'SGD', 'sgd_opt_learning_rate': 2.986739490682276e-05, 'sgd_opt_momentum': 0.07104027240883865}. Best is trial 12 with value: 0.859499990940094.
# [I 2022-04-17 13:22:03,661] Trial 15 finished with value: 0.7767999768257141 and parameters: {'n_layers': 1, 'weight_decay': 4.947014186954119e-08, 'n_units_l0': 112, 'optimizer': 'SGD', 'sgd_opt_learning_rate': 0.0015946802534818967, 'sgd_opt_momentum': 0.0994448300844597}. Best is trial 12 with value: 0.859499990940094.
# [I 2022-04-17 13:22:30,906] Trial 16 finished with value: 0.8639000058174133 and parameters: {'n_layers': 2, 'weight_decay': 7.106208623929293e-06, 'n_units_l0': 48, 'n_units_l1': 20, 'optimizer': 'SGD', 'sgd_opt_learning_rate': 0.09935457375047026, 'sgd_opt_momentum': 0.0012760411811983655}. Best is trial 16 with value: 0.8639000058174133.
# [I 2022-04-17 13:22:58,365] Trial 17 finished with value: 0.7792999744415283 and parameters: {'n_layers': 2, 'weight_decay': 0.0007943485930013916, 'n_units_l0': 56, 'n_units_l1': 18, 'optimizer': 'SGD', 'sgd_opt_learning_rate': 0.002553668708073083, 'sgd_opt_momentum': 0.0006659276279357769}. Best is trial 16 with value: 0.8639000058174133.
# [I 2022-04-17 13:23:27,230] Trial 18 finished with value: 0.8366000056266785 and parameters: {'n_layers': 2, 'weight_decay': 4.13732420676524e-06, 'n_units_l0': 110, 'n_units_l1': 24, 'optimizer': 'SGD', 'sgd_opt_learning_rate': 0.011072061623410392, 'sgd_opt_momentum': 0.0009576741348097887}. Best is trial 16 with value: 0.8639000058174133.
# [I 2022-04-17 13:24:02,632] Trial 19 finished with value: 0.6922000050544739 and parameters: {'n_layers': 3, 'weight_decay': 7.68521404481012e-06, 'n_units_l0': 16, 'n_units_l1': 14, 'n_units_l2': 114, 'optimizer': 'Adam', 'adam_learning_rate': 1.0225347027748768e-05}. Best is trial 16 with value: 0.8639000058174133.
# [I 2022-04-17 13:24:29,655] Trial 20 finished with value: 0.2687000036239624 and parameters: {'n_layers': 2, 'weight_decay': 3.4692130977153135e-08, 'n_units_l0': 29, 'n_units_l1': 118, 'optimizer': 'SGD', 'sgd_opt_learning_rate': 4.2417604197236544e-05, 'sgd_opt_momentum': 0.00015859935763725387}. Best is trial 16 with value: 0.8639000058174133.
# [I 2022-04-17 13:24:53,193] Trial 21 finished with value: 0.8661999702453613 and parameters: {'n_layers': 1, 'weight_decay': 1.7832185667408132e-07, 'n_units_l0': 58, 'optimizer': 'SGD', 'sgd_opt_learning_rate': 0.09576000601938675, 'sgd_opt_momentum': 0.01366998810831509}. Best is trial 21 with value: 0.8661999702453613.
# [I 2022-04-17 13:25:16,993] Trial 22 finished with value: 0.8671000003814697 and parameters: {'n_layers': 1, 'weight_decay': 1.3076203949520213e-06, 'n_units_l0': 59, 'optimizer': 'SGD', 'sgd_opt_learning_rate': 0.09869261598357779, 'sgd_opt_momentum': 0.007015691032513131}. Best is trial 22 with value: 0.8671000003814697.
# [I 2022-04-17 13:25:40,479] Trial 23 finished with value: 0.8273000121116638 and parameters: {'n_layers': 1, 'weight_decay': 1.267080015702314e-06, 'n_units_l0': 60, 'optimizer': 'SGD', 'sgd_opt_learning_rate': 0.009121745311153895, 'sgd_opt_momentum': 0.007136402036032602}. Best is trial 22 with value: 0.8671000003814697.
# [I 2022-04-17 13:26:07,865] Trial 24 finished with value: 0.6198999881744385 and parameters: {'n_layers': 2, 'weight_decay': 1.8476175433574386e-05, 'n_units_l0': 65, 'n_units_l1': 28, 'optimizer': 'SGD', 'sgd_opt_learning_rate': 0.0002475332165978157, 'sgd_opt_momentum': 0.00694698664450443}. Best is trial 22 with value: 0.8671000003814697.
# [I 2022-04-17 13:26:30,640] Trial 25 finished with value: 0.8320000171661377 and parameters: {'n_layers': 1, 'weight_decay': 6.542132822837975e-05, 'n_units_l0': 29, 'optimizer': 'SGD', 'sgd_opt_learning_rate': 0.014422579684084563, 'sgd_opt_momentum': 0.007924729490306282}. Best is trial 22 with value: 0.8671000003814697.
# [I 2022-04-17 13:26:59,793] Trial 26 finished with value: 0.8686000108718872 and parameters: {'n_layers': 2, 'weight_decay': 1.682058988413964e-08, 'n_units_l0': 124, 'n_units_l1': 8, 'optimizer': 'SGD', 'sgd_opt_learning_rate': 0.09859841209493356, 'sgd_opt_momentum': 0.018266654662239767}. Best is trial 26 with value: 0.8686000108718872.
# [I 2022-04-17 13:27:28,449] Trial 27 finished with value: 0.807200014591217 and parameters: {'n_layers': 1, 'weight_decay': 2.2271014689557653e-08, 'n_units_l0': 112, 'optimizer': 'Adam', 'adam_learning_rate': 0.05340276502062669}. Best is trial 26 with value: 0.8686000108718872.
# [I 2022-04-17 13:27:56,482] Trial 28 finished with value: 0.6299999952316284 and parameters: {'n_layers': 2, 'weight_decay': 3.474652141068412e-07, 'n_units_l0': 87, 'n_units_l1': 4, 'optimizer': 'SGD', 'sgd_opt_learning_rate': 0.004135042834985568, 'sgd_opt_momentum': 0.010334784259243116}. Best is trial 26 with value: 0.8686000108718872.
# [I 2022-04-17 13:28:28,849] Trial 29 finished with value: 0.3361999988555908 and parameters: {'n_layers': 3, 'weight_decay': 1.1548608123018247e-08, 'n_units_l0': 121, 'n_units_l1': 9, 'n_units_l2': 4, 'optimizer': 'SGD', 'sgd_opt_learning_rate': 0.000500325285511173, 'sgd_opt_momentum': 0.022761280521307853}. Best is trial 26 with value: 0.8686000108718872.
# [I 2022-04-17 13:29:02,644] Trial 30 finished with value: 0.8647000193595886 and parameters: {'n_layers': 3, 'weight_decay': 1.6269263555136215e-09, 'n_units_l0': 30, 'n_units_l1': 8, 'n_units_l2': 15, 'optimizer': 'Adam', 'adam_learning_rate': 0.001949939472611839}. Best is trial 26 with value: 0.8686000108718872.
# [I 2022-04-17 13:29:36,831] Trial 31 finished with value: 0.8668000102043152 and parameters: {'n_layers': 3, 'weight_decay': 7.212623914912706e-10, 'n_units_l0': 29, 'n_units_l1': 8, 'n_units_l2': 15, 'optimizer': 'Adam', 'adam_learning_rate': 0.0017463012413813477}. Best is trial 26 with value: 0.8686000108718872.
# [I 2022-04-17 13:30:11,759] Trial 32 finished with value: 0.8700000047683716 and parameters: {'n_layers': 3, 'weight_decay': 3.466223048668918e-10, 'n_units_l0': 59, 'n_units_l1': 6, 'n_units_l2': 10, 'optimizer': 'Adam', 'adam_learning_rate': 0.0019200388644631918}. Best is trial 32 with value: 0.8700000047683716.
# [I 2022-04-17 13:30:44,857] Trial 33 finished with value: 0.824999988079071 and parameters: {'n_layers': 3, 'weight_decay': 1.71200971894619e-10, 'n_units_l0': 10, 'n_units_l1': 6, 'n_units_l2': 10, 'optimizer': 'Adam', 'adam_learning_rate': 0.0021560120049389556}. Best is trial 32 with value: 0.8700000047683716.
# [I 2022-04-17 13:31:21,223] Trial 34 finished with value: 0.847000002861023 and parameters: {'n_layers': 3, 'weight_decay': 5.50261505319262e-10, 'n_units_l0': 94, 'n_units_l1': 4, 'n_units_l2': 9, 'optimizer': 'Adam', 'adam_learning_rate': 0.0006256575034147251}. Best is trial 32 with value: 0.8700000047683716.
# [I 2022-04-17 13:31:56,029] Trial 35 finished with value: 0.8511000275611877 and parameters: {'n_layers': 3, 'weight_decay': 9.751399192876859e-10, 'n_units_l0': 17, 'n_units_l1': 11, 'n_units_l2': 33, 'optimizer': 'Adam', 'adam_learning_rate': 0.007153856777545906}. Best is trial 32 with value: 0.8700000047683716.
# [I 2022-04-17 13:32:31,128] Trial 36 finished with value: 0.8334000110626221 and parameters: {'n_layers': 3, 'weight_decay': 5.4932445030345685e-09, 'n_units_l0': 70, 'n_units_l1': 6, 'n_units_l2': 7, 'optimizer': 'Adam', 'adam_learning_rate': 0.00022528096972523795}. Best is trial 32 with value: 0.8700000047683716.
# [I 2022-04-17 13:33:03,907] Trial 37 finished with value: 0.7383999824523926 and parameters: {'n_layers': 3, 'weight_decay': 3.0479618553262324e-10, 'n_units_l0': 4, 'n_units_l1': 12, 'n_units_l2': 26, 'optimizer': 'Adam', 'adam_learning_rate': 0.00617229513462118}. Best is trial 32 with value: 0.8700000047683716.
# [I 2022-04-17 13:33:38,901] Trial 38 finished with value: 0.8245999813079834 and parameters: {'n_layers': 3, 'weight_decay': 1.3526165933532254e-08, 'n_units_l0': 24, 'n_units_l1': 16, 'n_units_l2': 44, 'optimizer': 'Adam', 'adam_learning_rate': 6.415891662660092e-05}. Best is trial 32 with value: 0.8700000047683716.
# [I 2022-04-17 13:34:15,425] Trial 39 finished with value: 0.8597999811172485 and parameters: {'n_layers': 3, 'weight_decay': 1.3483435374955504e-09, 'n_units_l0': 86, 'n_units_l1': 5, 'n_units_l2': 17, 'optimizer': 'Adam', 'adam_learning_rate': 0.008926863513499889}. Best is trial 32 with value: 0.8700000047683716.
# [I 2022-04-17 13:34:42,980] Trial 40 finished with value: 0.7131999731063843 and parameters: {'n_layers': 2, 'weight_decay': 3.064262239224311e-09, 'n_units_l0': 13, 'n_units_l1': 9, 'optimizer': 'RMSprop', 'rmsprop_learning_rate': 0.04840236293860422, 'rmsprop_decay': 0.8529315334358851, 'rmsprop_momentum': 0.026977626849657724}. Best is trial 32 with value: 0.8700000047683716.
# [I 2022-04-17 13:35:13,584] Trial 41 finished with value: 0.8641999959945679 and parameters: {'n_layers': 2, 'weight_decay': 1.0909510770247353e-07, 'n_units_l0': 48, 'n_units_l1': 5, 'optimizer': 'Adam', 'adam_learning_rate': 0.0007259371246345269}. Best is trial 32 with value: 0.8700000047683716.
# [I 2022-04-17 13:35:39,471] Trial 42 finished with value: 0.6463000178337097 and parameters: {'n_layers': 1, 'weight_decay': 2.702463863118496e-10, 'n_units_l0': 59, 'optimizer': 'RMSprop', 'rmsprop_learning_rate': 0.0007323751505790232, 'rmsprop_decay': 0.982593636346471, 'rmsprop_momentum': 0.09821995544179316}. Best is trial 32 with value: 0.8700000047683716.
# [I 2022-04-17 13:36:14,522] Trial 43 finished with value: 0.8719000220298767 and parameters: {'n_layers': 3, 'weight_decay': 1.5110273882836714e-06, 'n_units_l0': 69, 'n_units_l1': 7, 'n_units_l2': 7, 'optimizer': 'Adam', 'adam_learning_rate': 0.002392835174044162}. Best is trial 43 with value: 0.8719000220298767.
# [I 2022-04-17 13:36:50,057] Trial 44 finished with value: 0.870199978351593 and parameters: {'n_layers': 3, 'weight_decay': 1.803267339210903e-06, 'n_units_l0': 73, 'n_units_l1': 8, 'n_units_l2': 7, 'optimizer': 'Adam', 'adam_learning_rate': 0.00219452269441551}. Best is trial 43 with value: 0.8719000220298767.
# [I 2022-04-17 13:37:24,782] Trial 45 finished with value: 0.8355000019073486 and parameters: {'n_layers': 3, 'weight_decay': 1.816471469311478e-06, 'n_units_l0': 72, 'n_units_l1': 6, 'n_units_l2': 7, 'optimizer': 'Adam', 'adam_learning_rate': 0.014869370775966052}. Best is trial 43 with value: 0.8719000220298767.
# [I 2022-04-17 13:38:00,835] Trial 46 finished with value: 0.8719000220298767 and parameters: {'n_layers': 3, 'weight_decay': 4.658597138763333e-07, 'n_units_l0': 98, 'n_units_l1': 4, 'n_units_l2': 6, 'optimizer': 'Adam', 'adam_learning_rate': 0.0037799788732831995}. Best is trial 43 with value: 0.8719000220298767.
# [I 2022-04-17 13:38:36,525] Trial 47 finished with value: 0.8589000105857849 and parameters: {'n_layers': 3, 'weight_decay': 6.819182015979689e-07, 'n_units_l0': 100, 'n_units_l1': 4, 'n_units_l2': 6, 'optimizer': 'Adam', 'adam_learning_rate': 0.003774873298516401}. Best is trial 43 with value: 0.8719000220298767.
# [I 2022-04-17 13:39:12,686] Trial 48 finished with value: 0.8658999800682068 and parameters: {'n_layers': 3, 'weight_decay': 3.5900296916898376e-07, 'n_units_l0': 79, 'n_units_l1': 5, 'n_units_l2': 5, 'optimizer': 'Adam', 'adam_learning_rate': 0.000842241267547301}. Best is trial 43 with value: 0.8719000220298767.
# [I 2022-04-17 13:39:49,792] Trial 49 finished with value: 0.7152000069618225 and parameters: {'n_layers': 3, 'weight_decay': 3.764710609245163e-06, 'n_units_l0': 125, 'n_units_l1': 7, 'n_units_l2': 9, 'optimizer': 'Adam', 'adam_learning_rate': 0.017279523263213983}. Best is trial 43 with value: 0.8719000220298767.
# [I 2022-04-17 13:40:25,523] Trial 50 finished with value: 0.8525999784469604 and parameters: {'n_layers': 3, 'weight_decay': 1.755846451964007e-05, 'n_units_l0': 96, 'n_units_l1': 7, 'n_units_l2': 10, 'optimizer': 'Adam', 'adam_learning_rate': 0.0037035751124778154}. Best is trial 43 with value: 0.8719000220298767.
# [I 2022-04-17 13:41:01,109] Trial 51 finished with value: 0.8483999967575073 and parameters: {'n_layers': 3, 'weight_decay': 1.1817764335157673e-06, 'n_units_l0': 75, 'n_units_l1': 4, 'n_units_l2': 5, 'optimizer': 'Adam', 'adam_learning_rate': 0.0004824166078444272}. Best is trial 43 with value: 0.8719000220298767.
# [I 2022-04-17 13:41:34,655] Trial 52 finished with value: 0.2689000070095062 and parameters: {'n_layers': 3, 'weight_decay': 4.694850877858309e-07, 'n_units_l0': 52, 'n_units_l1': 10, 'n_units_l2': 12, 'optimizer': 'RMSprop', 'rmsprop_learning_rate': 0.0008114464855303613, 'rmsprop_decay': 0.9505814723482888, 'rmsprop_momentum': 0.002636018596739065}. Best is trial 43 with value: 0.8719000220298767.
# [I 2022-04-17 13:42:11,408] Trial 53 finished with value: 0.8695999979972839 and parameters: {'n_layers': 3, 'weight_decay': 6.836014551953557e-06, 'n_units_l0': 101, 'n_units_l1': 13, 'n_units_l2': 7, 'optimizer': 'Adam', 'adam_learning_rate': 0.0016321838598243237}. Best is trial 43 with value: 0.8719000220298767.
# [I 2022-04-17 13:42:48,102] Trial 54 finished with value: 0.8783000111579895 and parameters: {'n_layers': 3, 'weight_decay': 4.382732710937403e-05, 'n_units_l0': 103, 'n_units_l1': 13, 'n_units_l2': 7, 'optimizer': 'Adam', 'adam_learning_rate': 0.0018235427146859136}. Best is trial 54 with value: 0.8783000111579895.
# [I 2022-04-17 13:43:25,464] Trial 55 finished with value: 0.8802000284194946 and parameters: {'n_layers': 3, 'weight_decay': 5.232258322142087e-05, 'n_units_l0': 98, 'n_units_l1': 13, 'n_units_l2': 7, 'optimizer': 'Adam', 'adam_learning_rate': 0.0018109888665265687}. Best is trial 55 with value: 0.8802000284194946.
# [I 2022-04-17 13:44:01,667] Trial 56 finished with value: 0.8740000128746033 and parameters: {'n_layers': 3, 'weight_decay': 0.00026878264085877584, 'n_units_l0': 86, 'n_units_l1': 15, 'n_units_l2': 6, 'optimizer': 'Adam', 'adam_learning_rate': 0.003329913714596725}. Best is trial 55 with value: 0.8802000284194946.
# [I 2022-04-17 13:44:38,278] Trial 57 finished with value: 0.8640999794006348 and parameters: {'n_layers': 3, 'weight_decay': 0.0005888440886731871, 'n_units_l0': 85, 'n_units_l1': 15, 'n_units_l2': 6, 'optimizer': 'Adam', 'adam_learning_rate': 0.0038325751078729315}. Best is trial 55 with value: 0.8802000284194946.
# [I 2022-04-17 13:45:13,855] Trial 58 finished with value: 0.8672000169754028 and parameters: {'n_layers': 3, 'weight_decay': 0.0002474460387493961, 'n_units_l0': 66, 'n_units_l1': 25, 'n_units_l2': 5, 'optimizer': 'Adam', 'adam_learning_rate': 0.003900786864582586}. Best is trial 55 with value: 0.8802000284194946.
# [I 2022-04-17 13:45:50,937] Trial 59 finished with value: 0.8720999956130981 and parameters: {'n_layers': 3, 'weight_decay': 4.5306816927555506e-05, 'n_units_l0': 105, 'n_units_l1': 18, 'n_units_l2': 7, 'optimizer': 'Adam', 'adam_learning_rate': 0.0009853360594955494}. Best is trial 55 with value: 0.8802000284194946.
# [I 2022-04-17 13:46:28,033] Trial 60 finished with value: 0.8733999729156494 and parameters: {'n_layers': 3, 'weight_decay': 4.083857043255282e-05, 'n_units_l0': 102, 'n_units_l1': 35, 'n_units_l2': 5, 'optimizer': 'Adam', 'adam_learning_rate': 0.0010846140792223422}. Best is trial 55 with value: 0.8802000284194946.
# [I 2022-04-17 13:47:05,587] Trial 61 finished with value: 0.8733000159263611 and parameters: {'n_layers': 3, 'weight_decay': 5.406270629882234e-05, 'n_units_l0': 107, 'n_units_l1': 53, 'n_units_l2': 5, 'optimizer': 'Adam', 'adam_learning_rate': 0.0011468702179552768}. Best is trial 55 with value: 0.8802000284194946.
# [I 2022-04-17 13:47:42,862] Trial 62 finished with value: 0.8615999817848206 and parameters: {'n_layers': 3, 'weight_decay': 5.08412209686559e-05, 'n_units_l0': 108, 'n_units_l1': 57, 'n_units_l2': 4, 'optimizer': 'Adam', 'adam_learning_rate': 0.0003713716155575608}. Best is trial 55 with value: 0.8802000284194946.
# [I 2022-04-17 13:48:20,306] Trial 63 finished with value: 0.8698999881744385 and parameters: {'n_layers': 3, 'weight_decay': 0.00013964891636789392, 'n_units_l0': 93, 'n_units_l1': 34, 'n_units_l2': 5, 'optimizer': 'Adam', 'adam_learning_rate': 0.0008799905916550325}. Best is trial 55 with value: 0.8802000284194946.
# [I 2022-04-17 13:48:57,953] Trial 64 finished with value: 0.8787999749183655 and parameters: {'n_layers': 3, 'weight_decay': 4.743407949675452e-05, 'n_units_l0': 128, 'n_units_l1': 53, 'n_units_l2': 6, 'optimizer': 'Adam', 'adam_learning_rate': 0.001165631676912909}. Best is trial 55 with value: 0.8802000284194946.
# [I 2022-04-17 13:49:36,515] Trial 65 finished with value: 0.8669999837875366 and parameters: {'n_layers': 3, 'weight_decay': 3.347145197420734e-05, 'n_units_l0': 125, 'n_units_l1': 71, 'n_units_l2': 4, 'optimizer': 'Adam', 'adam_learning_rate': 0.0011222405493635237}. Best is trial 55 with value: 0.8802000284194946.
# [I 2022-04-17 13:50:13,860] Trial 66 finished with value: 0.8745999932289124 and parameters: {'n_layers': 3, 'weight_decay': 0.00018598305255931123, 'n_units_l0': 114, 'n_units_l1': 43, 'n_units_l2': 8, 'optimizer': 'Adam', 'adam_learning_rate': 0.0012094702186636647}. Best is trial 55 with value: 0.8802000284194946.
# [I 2022-04-17 13:50:50,569] Trial 67 finished with value: 0.8367999792098999 and parameters: {'n_layers': 3, 'weight_decay': 0.00027850399639393984, 'n_units_l0': 85, 'n_units_l1': 45, 'n_units_l2': 5, 'optimizer': 'Adam', 'adam_learning_rate': 0.0002344187384575189}. Best is trial 55 with value: 0.8802000284194946.
# [I 2022-04-17 13:51:28,147] Trial 68 finished with value: 0.8741000294685364 and parameters: {'n_layers': 3, 'weight_decay': 0.0001193508651487553, 'n_units_l0': 112, 'n_units_l1': 67, 'n_units_l2': 4, 'optimizer': 'Adam', 'adam_learning_rate': 0.001254542768350897}. Best is trial 55 with value: 0.8802000284194946.
# [I 2022-04-17 13:52:04,437] Trial 69 finished with value: 0.10000000149011612 and parameters: {'n_layers': 3, 'weight_decay': 0.00014071858039139712, 'n_units_l0': 127, 'n_units_l1': 73, 'n_units_l2': 4, 'optimizer': 'RMSprop', 'rmsprop_learning_rate': 0.04049471412114975, 'rmsprop_decay': 0.8514715028339481, 'rmsprop_momentum': 0.0007001154598331011}. Best is trial 55 with value: 0.8802000284194946.
# [I 2022-04-17 13:52:41,243] Trial 70 finished with value: 0.866599977016449 and parameters: {'n_layers': 3, 'weight_decay': 0.00039952898473598765, 'n_units_l0': 117, 'n_units_l1': 35, 'n_units_l2': 8, 'optimizer': 'Adam', 'adam_learning_rate': 0.0013215820612482775}. Best is trial 55 with value: 0.8802000284194946.
# [I 2022-04-17 13:53:18,718] Trial 71 finished with value: 0.8827999830245972 and parameters: {'n_layers': 3, 'weight_decay': 9.054556583058834e-05, 'n_units_l0': 114, 'n_units_l1': 47, 'n_units_l2': 6, 'optimizer': 'Adam', 'adam_learning_rate': 0.0011830384718411779}. Best is trial 71 with value: 0.8827999830245972.
# [I 2022-04-17 13:53:57,393] Trial 72 finished with value: 0.8701000213623047 and parameters: {'n_layers': 3, 'weight_decay': 0.00012576844572464123, 'n_units_l0': 91, 'n_units_l1': 43, 'n_units_l2': 114, 'optimizer': 'Adam', 'adam_learning_rate': 0.00043825039891575015}. Best is trial 71 with value: 0.8827999830245972.
# [I 2022-04-17 13:54:35,221] Trial 73 finished with value: 0.8777999877929688 and parameters: {'n_layers': 3, 'weight_decay': 2.881712640886703e-05, 'n_units_l0': 113, 'n_units_l1': 69, 'n_units_l2': 6, 'optimizer': 'Adam', 'adam_learning_rate': 0.0014768290035539423}. Best is trial 71 with value: 0.8827999830245972.
# [I 2022-04-17 13:55:15,654] Trial 74 finished with value: 0.8855000138282776 and parameters: {'n_layers': 3, 'weight_decay': 8.454565095434013e-05, 'n_units_l0': 115, 'n_units_l1': 93, 'n_units_l2': 81, 'optimizer': 'Adam', 'adam_learning_rate': 0.0023754038805213753}. Best is trial 74 with value: 0.8855000138282776.
# [I 2022-04-17 13:55:55,586] Trial 75 finished with value: 0.8816999793052673 and parameters: {'n_layers': 3, 'weight_decay': 1.1347868300691378e-05, 'n_units_l0': 111, 'n_units_l1': 94, 'n_units_l2': 70, 'optimizer': 'Adam', 'adam_learning_rate': 0.0015982917130051557}. Best is trial 74 with value: 0.8855000138282776.
# [I 2022-04-17 13:56:31,738] Trial 76 finished with value: 0.8449000120162964 and parameters: {'n_layers': 3, 'weight_decay': 2.5477375548200553e-05, 'n_units_l0': 7, 'n_units_l1': 94, 'n_units_l2': 88, 'optimizer': 'Adam', 'adam_learning_rate': 0.002187388910156192}. Best is trial 74 with value: 0.8855000138282776.
# [I 2022-04-17 13:57:11,497] Trial 77 finished with value: 0.8758999705314636 and parameters: {'n_layers': 3, 'weight_decay': 1.1707274402190143e-05, 'n_units_l0': 111, 'n_units_l1': 84, 'n_units_l2': 88, 'optimizer': 'Adam', 'adam_learning_rate': 0.001596215333350803}. Best is trial 74 with value: 0.8855000138282776.
# [I 2022-04-17 13:57:52,456] Trial 78 finished with value: 0.10090000182390213 and parameters: {'n_layers': 3, 'weight_decay': 8.525999949348462e-06, 'n_units_l0': 126, 'n_units_l1': 87, 'n_units_l2': 78, 'optimizer': 'Adam', 'adam_learning_rate': 0.09636027052487739}. Best is trial 74 with value: 0.8855000138282776.
# [I 2022-04-17 13:58:32,888] Trial 79 finished with value: 0.8783000111579895 and parameters: {'n_layers': 3, 'weight_decay': 1.2556745979225182e-05, 'n_units_l0': 114, 'n_units_l1': 116, 'n_units_l2': 68, 'optimizer': 'Adam', 'adam_learning_rate': 0.0006492555188952031}. Best is trial 74 with value: 0.8855000138282776.
# [I 2022-04-17 13:59:12,205] Trial 80 finished with value: 0.8802000284194946 and parameters: {'n_layers': 3, 'weight_decay': 7.642799659902656e-05, 'n_units_l0': 80, 'n_units_l1': 126, 'n_units_l2': 57, 'optimizer': 'Adam', 'adam_learning_rate': 0.00055872986859218}. Best is trial 74 with value: 0.8855000138282776.
# [I 2022-04-17 13:59:51,056] Trial 81 finished with value: 0.8812999725341797 and parameters: {'n_layers': 3, 'weight_decay': 8.049283499750196e-05, 'n_units_l0': 79, 'n_units_l1': 125, 'n_units_l2': 63, 'optimizer': 'Adam', 'adam_learning_rate': 0.000534790031811908}. Best is trial 74 with value: 0.8855000138282776.
# [I 2022-04-17 14:00:30,538] Trial 82 finished with value: 0.8806999921798706 and parameters: {'n_layers': 3, 'weight_decay': 8.371293643886615e-05, 'n_units_l0': 91, 'n_units_l1': 120, 'n_units_l2': 56, 'optimizer': 'Adam', 'adam_learning_rate': 0.0005828724718768256}. Best is trial 74 with value: 0.8855000138282776.
# [I 2022-04-17 14:01:09,515] Trial 83 finished with value: 0.8705000281333923 and parameters: {'n_layers': 3, 'weight_decay': 7.878096164990612e-05, 'n_units_l0': 79, 'n_units_l1': 128, 'n_units_l2': 56, 'optimizer': 'Adam', 'adam_learning_rate': 0.00027323955837058213}. Best is trial 74 with value: 0.8855000138282776.
# [I 2022-04-17 14:01:48,960] Trial 84 finished with value: 0.8799999952316284 and parameters: {'n_layers': 3, 'weight_decay': 1.7689416731137262e-05, 'n_units_l0': 78, 'n_units_l1': 111, 'n_units_l2': 60, 'optimizer': 'Adam', 'adam_learning_rate': 0.0005935316829499988}. Best is trial 74 with value: 0.8855000138282776.
# [I 2022-04-17 14:02:27,350] Trial 85 finished with value: 0.8762999773025513 and parameters: {'n_layers': 3, 'weight_decay': 8.283323683286401e-05, 'n_units_l0': 66, 'n_units_l1': 108, 'n_units_l2': 46, 'optimizer': 'Adam', 'adam_learning_rate': 0.0005520534288591255}. Best is trial 74 with value: 0.8855000138282776.
# [I 2022-04-17 14:03:03,345] Trial 86 finished with value: 0.7354000210762024 and parameters: {'n_layers': 3, 'weight_decay': 2.0533062930094974e-05, 'n_units_l0': 79, 'n_units_l1': 104, 'n_units_l2': 61, 'optimizer': 'RMSprop', 'rmsprop_learning_rate': 0.004412964003638894, 'rmsprop_decay': 0.9505822908764768, 'rmsprop_momentum': 0.00728559806438384}. Best is trial 74 with value: 0.8855000138282776.
# [I 2022-04-17 14:03:42,117] Trial 87 finished with value: 0.8666999936103821 and parameters: {'n_layers': 3, 'weight_decay': 0.0004726417915510477, 'n_units_l0': 92, 'n_units_l1': 128, 'n_units_l2': 36, 'optimizer': 'Adam', 'adam_learning_rate': 0.0001312733656410145}. Best is trial 74 with value: 0.8855000138282776.
# [I 2022-04-17 14:04:20,205] Trial 88 finished with value: 0.8776000142097473 and parameters: {'n_layers': 3, 'weight_decay': 7.512781882963544e-05, 'n_units_l0': 63, 'n_units_l1': 96, 'n_units_l2': 74, 'optimizer': 'Adam', 'adam_learning_rate': 0.00033244116407546816}. Best is trial 74 with value: 0.8855000138282776.
# [I 2022-04-17 14:04:53,120] Trial 89 finished with value: 0.8708999752998352 and parameters: {'n_layers': 2, 'weight_decay': 0.00018822302683454165, 'n_units_l0': 54, 'n_units_l1': 78, 'optimizer': 'Adam', 'adam_learning_rate': 0.0006779706116525545}. Best is trial 74 with value: 0.8855000138282776.
# [I 2022-04-17 14:05:31,036] Trial 90 finished with value: 0.871999979019165 and parameters: {'n_layers': 3, 'weight_decay': 0.0008987871472706374, 'n_units_l0': 44, 'n_units_l1': 110, 'n_units_l2': 96, 'optimizer': 'Adam', 'adam_learning_rate': 0.002712973137706509}. Best is trial 74 with value: 0.8855000138282776.
# [I 2022-04-17 14:06:10,672] Trial 91 finished with value: 0.8841999769210815 and parameters: {'n_layers': 3, 'weight_decay': 1.5269041124892512e-05, 'n_units_l0': 98, 'n_units_l1': 87, 'n_units_l2': 54, 'optimizer': 'Adam', 'adam_learning_rate': 0.0007143131685269261}. Best is trial 74 with value: 0.8855000138282776.
# [I 2022-04-17 14:06:50,029] Trial 92 finished with value: 0.8726999759674072 and parameters: {'n_layers': 3, 'weight_decay': 1.5744657206741316e-05, 'n_units_l0': 93, 'n_units_l1': 89, 'n_units_l2': 53, 'optimizer': 'Adam', 'adam_learning_rate': 0.0005395149440514377}. Best is trial 74 with value: 0.8855000138282776.
# [I 2022-04-17 14:07:29,374] Trial 93 finished with value: 0.8190000057220459 and parameters: {'n_layers': 3, 'weight_decay': 5.036231176420621e-06, 'n_units_l0': 76, 'n_units_l1': 119, 'n_units_l2': 63, 'optimizer': 'Adam', 'adam_learning_rate': 1.517619423859782e-05}. Best is trial 74 with value: 0.8855000138282776.
# [I 2022-04-17 14:08:08,282] Trial 94 finished with value: 0.8820000290870667 and parameters: {'n_layers': 3, 'weight_decay': 2.683930280918612e-05, 'n_units_l0': 82, 'n_units_l1': 100, 'n_units_l2': 44, 'optimizer': 'Adam', 'adam_learning_rate': 0.0007694105579536667}. Best is trial 74 with value: 0.8855000138282776.
# [I 2022-04-17 14:08:48,367] Trial 95 finished with value: 0.8672000169754028 and parameters: {'n_layers': 3, 'weight_decay': 2.6045464069872793e-05, 'n_units_l0': 83, 'n_units_l1': 101, 'n_units_l2': 44, 'optimizer': 'Adam', 'adam_learning_rate': 0.0001525200148126075}. Best is trial 74 with value: 0.8855000138282776.
# [I 2022-04-17 14:09:26,145] Trial 96 finished with value: 0.8726000189781189 and parameters: {'n_layers': 3, 'weight_decay': 9.7130859606519e-05, 'n_units_l0': 70, 'n_units_l1': 81, 'n_units_l2': 39, 'optimizer': 'Adam', 'adam_learning_rate': 0.0007526781133888668}. Best is trial 74 with value: 0.8855000138282776.
# [I 2022-04-17 14:10:04,601] Trial 97 finished with value: 0.8744000196456909 and parameters: {'n_layers': 3, 'weight_decay': 1.0711794598928278e-05, 'n_units_l0': 97, 'n_units_l1': 96, 'n_units_l2': 28, 'optimizer': 'Adam', 'adam_learning_rate': 0.00034226239056374234}. Best is trial 74 with value: 0.8855000138282776.
# [I 2022-04-17 14:10:43,509] Trial 98 finished with value: 0.8781999945640564 and parameters: {'n_layers': 3, 'weight_decay': 2.839136567555215e-06, 'n_units_l0': 88, 'n_units_l1': 114, 'n_units_l2': 48, 'optimizer': 'Adam', 'adam_learning_rate': 0.00046540124925010504}. Best is trial 74 with value: 0.8855000138282776.
# [I 2022-04-17 14:11:22,141] Trial 99 finished with value: 0.859499990940094 and parameters: {'n_layers': 3, 'weight_decay': 6.69050986485281e-05, 'n_units_l0': 74, 'n_units_l1': 104, 'n_units_l2': 58, 'optimizer': 'Adam', 'adam_learning_rate': 0.0052765874377641315}. Best is trial 74 with value: 0.8855000138282776.
# Number of finished trials:  100
# Best trial:
#   Value:  0.8855000138282776
#   Params:
#     n_layers: 3
#     weight_decay: 8.454565095434013e-05
#     n_units_l0: 115
#     n_units_l1: 93
#     n_units_l2: 81
#     optimizer: Adam
#     adam_learning_rate: 0.0023754038805213753
